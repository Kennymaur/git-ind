# %% [markdown]
# # Title
# ### Indian Startup Ecosystem Analysis

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Objective
#
# The objective of this project is to explore and find insights from the data on funding to Startups in India from **2018 to 2021**, and advise a team on thier next step as the try to venture in the Indian startup ecosystem.

# %% [markdown]
# ## Hypothesis
# **Null Hypothesis** : Funding to startup is centralized around a few locations and sectors
#
# **Alternate Hypothesis** : Funding to startup is spred across different locations and sectors

# %% [markdown]
# ## Research Questions
#
#
# Which Industry received the highest amount of funding?
#
# Which industry received the lowest amount of funding?
#
# Which location recorded the highest amount of funding received?
#
# What is the average amount of funding received in top ten sectors?
#
# How many companies received funded in each year?
#
# Which company received the highest amount of funds?
#
# Which company received the lowest amount of funds ?

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np 
import datetime as dt

# %%
data_2018=pd.read_csv('../data/startup_funding2018.csv')

# %%
data_2018
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series       Amount                          Location  \
# ...

# %%
data_2018.columns
# Out:
# Index(['Company Name', 'Industry', 'Round/Series', 'Amount', 'Location',
#        'About Company'],
#       dtype='object')

# %%
data_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB

# %%
data_2019=pd.read_csv('../data/startup_funding2019.csv')
data_2019
# Out:
#       Company/Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving      NaN         NaN                Ecommerce
# 1         Ruangguru   2014.0      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane   2014.0     Chennai          Interior design
# 4          Nu Genes   2004.0   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo   2013.0    Gurugram              Hospitality
# 86       GoMechanic   2016.0       Delhi  Automobile & Technology
# 87           Spinny   2015.0       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# ...

# %%
data_2019.columns
# Out:
# Index(['Company/Brand', 'Founded', 'HeadQuarter', 'Sector', 'What it does',
#        'Founders', 'Investor', 'Amount($)', 'Stage'],
#       dtype='object')

# %%
data_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %%
data_2020=pd.read_csv('../data/startup_funding2020.csv')
data_2020
# Out:
#      Company/Brand Founded HeadQuarter              Sector  \
# 0       Aqgromalin    2019     Chennai            AgriTech
# 1         Krayonnz    2019   Bangalore              EdTech
# 2     PadCare Labs    2018        Pune  Hygiene management
# 3            NCOME    2020   New Delhi              Escrow
# 4       Gramophone    2016      Indore            AgriTech
# ...            ...     ...         ...                 ...
# 1050  Leverage Edu     NaN       Delhi              Edtech
# 1051         EpiFi     NaN         NaN             Fintech
# 1052       Purplle    2012      Mumbai           Cosmetics
# 1053        Shuttl    2015       Delhi           Transport
# 1054         Pando    2017     Chennai            Logitech
#
#                                            What it does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# ...

# %%
data_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1055 non-null   object
#  1   Founded        843 non-null    object
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What it does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount($)      1052 non-null   object
#  8   Stage          591 non-null    object
#  9   Unnamed: 9     2 non-null      object
# dtypes: object(10)
# memory usage: 82.5+ KB

# %%
data_2020['Unnamed: 9']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1050    NaN
# 1051    NaN
# 1052    NaN
# 1053    NaN
# 1054    NaN
# Name: Unnamed: 9, Length: 1055, dtype: object

# %%
data_2021=pd.read_csv('../data/startup_funding2021.csv')
data_2021
# Out:
#        Company/Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics   2019.0   Bangalore             AI startup
# 1             upGrad   2015.0      Mumbai                 EdTech
# 2        Lead School   2012.0      Mumbai                 EdTech
# 3            Bizongo   2015.0      Mumbai         B2B E-commerce
# 4           FypMoney   2021.0    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce   2019.0    Gurugram  Staffing & Recruiting
# 1205          Vahdam   2015.0   New Delhi       Food & Beverages
# 1206    Leap Finance   2019.0   Bangalore     Financial Services
# 1207    CollegeDekho   2015.0    Gurugram                 EdTech
# 1208          WeRize   2019.0   Bangalore     Financial Services
#
#                                            What it does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# ...

# %%
data_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount($)      1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB

# %%
#2018 cleaning
data_2018.head(60)
# Out:
#                               Company Name  \
# 0                          TheCollegeFever
# 1                          Happy Cow Dairy
# 2                               MyLoanCare
# 3                              PayMe India
# 4                                 Eunimart
# 5                                   Hasura
# 6                                Tripshelf
# 7                             Hyperdata.IO
# 8                             Freightwalla
# 9                       Microchip Payments
# 10              BizCrum Infotech Pvt. Ltd.
# 11                                 Emojifi
# 12                                   Flock
# 13                               Freshboxx
# 14              Wide Mobility Mechatronics
# 15                                 Pitstop
# 16                                  Mihuru
# 17                                    Fyle
# 18                                AppWharf
# 19        Antariksh Waste Ventures Pvt ltd
# 20                                Cogoport
# ...

# %%
data_2018['Industry'] = data_2018['Industry'].apply(str)
data_2018['Industry'] = data_2018['Industry'].str.split(',').str[0]
data_2018['Industry'] = data_2018['Industry'].replace("'","",regex=True)

# %%
data_2018['Industry'].value_counts().head(100)
# Out:
# —                     30
# Financial Services    26
# Health Care           26
# E-Commerce            22
# Apps                  20
#                       ..
# Cosmetics              1
# Online Games           1
# Battery                1
# Music                  1
# Commercial             1
# Name: Industry, Length: 100, dtype: int64

# %%
with pd.option_context('display.max_rows', None):
  print(data_2018['Industry'])
# Out:
# 0                         Brand Marketing
# 1                             Agriculture
# 2                                  Credit
# 3                      Financial Services
# 4                    E-Commerce Platforms
# 5                    Cloud Infrastructure
# 6                                Internet
# 7                         Market Research
# 8                    Information Services
# 9                         Mobile Payments
# 10                                    B2B
# 11                               Internet
# 12                                   Apps
# 13                          Food Delivery
# 14                  Industrial Automation
# 15                             Automotive
# 16                                Finance
# 17                             Accounting
# 18                Artificial Intelligence
# 19                     Internet of Things
# 20                     Air Transportation
# 21                     Financial Services
# ...

# %%
data_2018['Location']
# Out:
# 0           Bangalore, Karnataka, India
# 1            Mumbai, Maharashtra, India
# 2               Gurgaon, Haryana, India
# 3           Noida, Uttar Pradesh, India
# 4      Hyderabad, Andhra Pradesh, India
#                      ...
# 521         Bangalore, Karnataka, India
# 522             Haryana, Haryana, India
# 523          Mumbai, Maharashtra, India
# 524          Mumbai, Maharashtra, India
# 525          Chennai, Tamil Nadu, India
# Name: Location, Length: 526, dtype: object

# %%
data_2018['Location'] = data_2018['Location'].apply(str)
data_2018['Location'] = data_2018['Location'].str.split(',').str[0]
data_2018['Location'] = data_2018['Location'].replace("'","",regex=True)

# %%
with pd.option_context('display.max_rows',None):
    print(data_2018['Location'])
# Out:
# 0           Bangalore
# 1              Mumbai
# 2             Gurgaon
# 3               Noida
# 4           Hyderabad
# 5           Bengaluru
# 6             Kalkaji
# 7           Hyderabad
# 8              Mumbai
# 9           Bangalore
# 10              Delhi
# 11          Bengaluru
# 12              India
# 13              Hubli
# 14          Bangalore
# 15          Bengaluru
# 16             Mumbai
# 17          Bengaluru
# 18          New Delhi
# 19            Chennai
# 20             Mumbai
# 21             Mumbai
# 22          New Delhi
# 23              Delhi
# 24          Bengaluru
# 25             Mohali
# 26            Chennai
# 27             Mumbai
# 28             Mumbai
# 29          Hyderabad
# 30          New Delhi
# 31            Kolkata
# 32          Bangalore
# 33          Bengaluru
# 34             Mumbai
# 35          Bengaluru
# 36             Mumbai
# 37          New Delhi
# 38             Mumbai
# 39            Chennai
# 40          New Delhi
# ...

# %%
with pd.option_context('display.max_rows',None):
    print(data_2018['Amount'])
# Out:
# 0               250000
# 1          ₹40,000,000
# 2          ₹65,000,000
# 3              2000000
# 4                    —
# 5              1600000
# 6          ₹16,000,000
# 7          ₹50,000,000
# 8                    —
# 9                    —
# 10                   —
# 11                   —
# 12                   —
# 13                   —
# 14                   —
# 15        ₹100,000,000
# 16              150000
# 17             1100000
# 18                   —
# 19            ₹500,000
# 20             6000000
# 21              650000
# 22         ₹35,000,000
# 23         ₹64,000,000
# 24                   —
# 25                   —
# 26             2000000
# 27             2000000
# 28             2000000
# 29                   —
# 30         ₹20,000,000
# 31             1000000
# 32                   —
# 33              650000
# 34             1000000
# 35             5000000
# 36             4000000
# 37         ₹30,000,000
# 38             1000000
# 39             2800000
# ...

# %%
data_2018['Curency']=np.where(data_2018.Amount.str.contains('₹'),'INR','USD')

# %%
data_2018['Currency_Rate_Date'] = dt.datetime(2018,12,31)

# %%
data_2018['Amount']=data_2018['Amount'].replace('[\—,]' , '0' , regex=True)

# %%
data_2018['Amount'] = data_2018['Amount'].replace({'\$': '', '\₹': ''}, regex=True).astype(float)

# %%
data_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company Name        526 non-null    object
#  1   Industry            526 non-null    object
#  2   Round/Series        526 non-null    object
#  3   Amount              526 non-null    float64
#  4   Location            526 non-null    object
#  5   About Company       526 non-null    object
#  6   Curency             526 non-null    object
#  7   Currency_Rate_Date  526 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 33.0+ KB

# %%
from forex_python.converter import CurrencyRates

# %%
r = CurrencyRates()
data_2018['Amount($)'] = data_2018.apply(lambda x: r.convert(x.Curency, 'USD', x.Amount, x.Currency_Rate_Date), axis = 1)

# %%
data_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company Name        526 non-null    object
#  1   Industry            526 non-null    object
#  2   Round/Series        526 non-null    object
#  3   Amount              526 non-null    float64
#  4   Location            526 non-null    object
#  5   About Company       526 non-null    object
#  6   Curency             526 non-null    object
#  7   Currency_Rate_Date  526 non-null    datetime64[ns]
#  8   Amount($)           526 non-null    float64
# dtypes: datetime64[ns](1), float64(2), object(6)
# memory usage: 37.1+ KB

# %%
data_2018
# Out:
#           Company Name                Industry Round/Series        Amount  \
# 0      TheCollegeFever         Brand Marketing         Seed  2.500000e+05
# 1      Happy Cow Dairy             Agriculture         Seed  4.000000e+09
# 2           MyLoanCare                  Credit     Series A  6.500000e+09
# 3          PayMe India      Financial Services        Angel  2.000000e+06
# 4             Eunimart    E-Commerce Platforms         Seed  0.000000e+00
# ..                 ...                     ...          ...           ...
# 521              Udaan                     B2B     Series C  2.250000e+08
# 522  Happyeasygo Group                 Tourism     Series A  0.000000e+00
# 523             Mombay       Food and Beverage         Seed  7.500000e+03
# 524         Droni Tech  Information Technology         Seed  3.500000e+09
# 525            Netmeds           Biotechnology     Series C  3.500000e+07
#
#       Location                                      About Company Curency  \
# ...

# %%
data_2018['Amount($)']=data_2018['Amount($)'].apply(lambda x:'%.2f' % x)

# %%
data_2018['Amount']=data_2018['Amount'].apply(lambda x:'%.2f' % x)

# %%
data_2018
# Out:
#           Company Name                Industry Round/Series         Amount  \
# 0      TheCollegeFever         Brand Marketing         Seed      250000.00
# 1      Happy Cow Dairy             Agriculture         Seed  4000000000.00
# 2           MyLoanCare                  Credit     Series A  6500000000.00
# 3          PayMe India      Financial Services        Angel     2000000.00
# 4             Eunimart    E-Commerce Platforms         Seed           0.00
# ..                 ...                     ...          ...            ...
# 521              Udaan                     B2B     Series C   225000000.00
# 522  Happyeasygo Group                 Tourism     Series A           0.00
# 523             Mombay       Food and Beverage         Seed        7500.00
# 524         Droni Tech  Information Technology         Seed  3500000000.00
# 525            Netmeds           Biotechnology     Series C    35000000.00
#
# ...

# %%
data_2018['Amount'].unique()
# Out:
# array(['250000.00', '4000000000.00', '6500000000.00', '2000000.00',
#        '0.00', '1600000.00', '1600000000.00', '5000000000.00',
#        '10000000000.00', '150000.00', '1100000.00', '5000000.00',
#        '6000000.00', '650000.00', '3500000000.00', '6400000000.00',
#        '2000000000.00', '1000000.00', '4000000.00', '3000000000.00',
#        '2800000.00', '1700000.00', '1300000.00', '500000000.00',
#        '1205000000.00', '1500000000.00', '500000.00', '10400000000.00',
#        '4500000000.00', '13400000.00', '2500000000.00', '2604000000.00',
#        '800000000.00', '600000.00', '9000000.00', '100000.00', '20000.00',
#        '120000.00', '3400000000.00', '34200000000.00', '1430145.00',
#        '60000000000.00', '74200000000.00', '1000000000000.00',
#        '2000000000000.00', '309800000.00', '25000000000.00',
#        '700000000.00', '55000000000.00', '2805000000.00', '200000000.00',
#        '24000000000.00', '12000000000.00', '204000000.00',
# ...

# %%
data_2018['Amount'].astype(float)
# Out:
# 0      2.500000e+05
# 1      4.000000e+09
# 2      6.500000e+09
# 3      2.000000e+06
# 4      0.000000e+00
#            ...
# 521    2.250000e+08
# 522    0.000000e+00
# 523    7.500000e+03
# 524    3.500000e+09
# 525    3.500000e+07
# Name: Amount, Length: 526, dtype: float64

# %%
pd.options.display.float_format= '{:.2f}'.format

# %%
data_2018.head(10)
# Out:
#          Company Name              Industry Round/Series         Amount  \
# 0     TheCollegeFever       Brand Marketing         Seed      250000.00
# 1     Happy Cow Dairy           Agriculture         Seed  4000000000.00
# 2          MyLoanCare                Credit     Series A  6500000000.00
# 3         PayMe India    Financial Services        Angel     2000000.00
# 4            Eunimart  E-Commerce Platforms         Seed           0.00
# 5              Hasura  Cloud Infrastructure         Seed     1600000.00
# 6           Tripshelf              Internet         Seed  1600000000.00
# 7        Hyperdata.IO       Market Research        Angel  5000000000.00
# 8        Freightwalla  Information Services         Seed           0.00
# 9  Microchip Payments       Mobile Payments         Seed           0.00
#
#     Location                                      About Company Curency  \
# 0  Bangalore  TheCollegeFever is a hub for fun, fiesta and f...     USD
# ...

# %%
data_2018 = data_2018.rename(columns =  {'Company Name':'Company/Brand', 'Industry':'Sector', 'Location':'HeadQuarter','Round/Series':'Stage', 'About Company':'What it does'} )

# %%
data_2018.drop(['Curency'],inplace=True, axis=1)

# %%
data_2018.drop(['Currency_Rate_Date'],inplace=True, axis=1)
data_2018.drop(['Amount'],inplace=True, axis=1)

# %%
data_2018['Stage'].unique()
# Out:
# array(['Seed', 'Series A', 'Angel', 'Series B', 'Pre-Seed',
#        'Private Equity', 'Venture - Series Unknown', 'Grant',
#        'Debt Financing', 'Post-IPO Debt', 'Series H', 'Series C',
#        'Series E', 'Corporate Round', 'Undisclosed',
#        'https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593',
#        'Series D', 'Secondary Market', 'Post-IPO Equity',
#        'Non-equity Assistance', 'Funding Round'], dtype=object)

# %%
data_2018['Stage']=data_2018['Stage'].replace(['https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593'],['Undiscloded'])

# %%
data_2018['HeadQuarter'].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurgaon', 'Noida', 'Hyderabad',
#        'Bengaluru', 'Kalkaji', 'Delhi', 'India', 'Hubli', 'New Delhi',
#        'Chennai', 'Mohali', 'Kolkata', 'Pune', 'Jodhpur', 'Kanpur',
#        'Ahmedabad', 'Azadpur', 'Haryana', 'Cochin', 'Faridabad', 'Jaipur',
#        'Kota', 'Anand', 'Bangalore City', 'Belgaum', 'Thane', 'Margão',
#        'Indore', 'Alwar', 'Kannur', 'Trivandrum', 'Ernakulam',
#        'Kormangala', 'Uttar Pradesh', 'Andheri', 'Mylapore', 'Ghaziabad',
#        'Kochi', 'Powai', 'Guntur', 'Kalpakkam', 'Bhopal', 'Coimbatore',
#        'Worli', 'Alleppey', 'Chandigarh', 'Guindy', 'Lucknow'],
#       dtype=object)

# %%
with pd.option_context('display.max_rows',None):
    print(data_2018['HeadQuarter'])
# Out:
# 0           Bangalore
# 1              Mumbai
# 2             Gurgaon
# 3               Noida
# 4           Hyderabad
# 5           Bengaluru
# 6             Kalkaji
# 7           Hyderabad
# 8              Mumbai
# 9           Bangalore
# 10              Delhi
# 11          Bengaluru
# 12              India
# 13              Hubli
# 14          Bangalore
# 15          Bengaluru
# 16             Mumbai
# 17          Bengaluru
# 18          New Delhi
# 19            Chennai
# 20             Mumbai
# 21             Mumbai
# 22          New Delhi
# 23              Delhi
# 24          Bengaluru
# 25             Mohali
# 26            Chennai
# 27             Mumbai
# 28             Mumbai
# 29          Hyderabad
# 30          New Delhi
# 31            Kolkata
# 32          Bangalore
# 33          Bengaluru
# 34             Mumbai
# 35          Bengaluru
# 36             Mumbai
# 37          New Delhi
# 38             Mumbai
# 39            Chennai
# 40          New Delhi
# ...

# %%
data_2019
# Out:
#       Company/Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving      NaN         NaN                Ecommerce
# 1         Ruangguru  2014.00      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane  2014.00     Chennai          Interior design
# 4          Nu Genes  2004.00   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo  2013.00    Gurugram              Hospitality
# 86       GoMechanic  2016.00       Delhi  Automobile & Technology
# 87           Spinny  2015.00       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# ...

# %%
data_2019['Amount($)'] = data_2019['Amount($)'].replace({'\$':''}, regex = True)

# %%
data_2020['Amount($)'] = data_2020['Amount($)'].replace({'\$':''}, regex = True)

# %%
data_2021['Amount($)'] = data_2021['Amount($)'].replace({'\$':''}, regex = True)

# %%
sets=[data_2018,data_2019,data_2020, data_2021]
df = pd.concat(sets)

# %%
df
# Out:
#         Company/Brand                 Sector         Stage HeadQuarter  \
# 0     TheCollegeFever        Brand Marketing          Seed   Bangalore
# 1     Happy Cow Dairy            Agriculture          Seed      Mumbai
# 2          MyLoanCare                 Credit      Series A     Gurgaon
# 3         PayMe India     Financial Services         Angel       Noida
# 4            Eunimart   E-Commerce Platforms          Seed   Hyderabad
# ...               ...                    ...           ...         ...
# 1204         Gigforce  Staffing & Recruiting  Pre-series A    Gurugram
# 1205           Vahdam       Food & Beverages      Series D   New Delhi
# 1206     Leap Finance     Financial Services      Series C   Bangalore
# 1207     CollegeDekho                 EdTech      Series B    Gurugram
# 1208           WeRize     Financial Services      Series A   Bangalore
#
#                                            What it does    Amount($) Founded  \
# ...

# %%
with pd.option_context('display.max_rows',None):
    print(df)
# Out:
#                                           Company/Brand  \
# 0                                       TheCollegeFever
# 1                                       Happy Cow Dairy
# 2                                            MyLoanCare
# 3                                           PayMe India
# 4                                              Eunimart
# 5                                                Hasura
# 6                                             Tripshelf
# 7                                          Hyperdata.IO
# 8                                          Freightwalla
# 9                                    Microchip Payments
# 10                           BizCrum Infotech Pvt. Ltd.
# 11                                              Emojifi
# 12                                                Flock
# 13                                            Freshboxx
# 14                           Wide Mobility Mechatronics
# 15                                              Pitstop
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2879 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  2879 non-null   object
#  1   Sector         2861 non-null   object
#  2   Stage          1941 non-null   object
#  3   HeadQuarter    2765 non-null   object
#  4   What it does   2879 non-null   object
#  5   Amount($)      2873 non-null   object
#  6   Founded        2111 non-null   object
#  7   Founders       2334 non-null   object
#  8   Investor       2253 non-null   object
#  9   Unnamed: 9     2 non-null      object
# dtypes: object(10)
# memory usage: 247.4+ KB

# %%
df['Sector'].unique()
# Out:
# array(['Brand Marketing', 'Agriculture', 'Credit', 'Financial Services',
#        'E-Commerce Platforms', 'Cloud Infrastructure', 'Internet',
#        'Market Research', 'Information Services', 'Mobile Payments',
#        'B2B', 'Apps', 'Food Delivery', 'Industrial Automation',
#        'Automotive', 'Finance', 'Accounting', 'Artificial Intelligence',
#        'Internet of Things', 'Air Transportation', 'Food and Beverage',
#        'Autonomous Vehicles', 'Enterprise Software', 'Logistics',
#        'Insurance', 'Information Technology', 'Blockchain', 'Education',
#        'E-Commerce', 'Renewable Energy', 'E-Learning', 'Clean Energy',
#        'Transportation', 'Fitness', 'Hospitality',
#        'Media and Entertainment', 'Broadcasting', 'EdTech', 'Health Care',
#        '—', 'Sports', 'Big Data', 'Cloud Computing', 'Food Processing',
#        'Trading Platform', 'Consumer Goods', 'Wellness', 'Fashion',
#        'Consulting', 'Biotechnology', 'Communities', 'Consumer',
# ...

# %%
df['Amount($)'].unique()
# Out:
# array(['250000.00', '57444017.17', '93346527.90', '2000000.00', '0.00',
#        '1600000.00', '22977606.87', '71805021.46', '143610042.92',
#        '150000.00', '1100000.00', '71805.02', '6000000.00', '650000.00',
#        '50263515.02', '91910427.47', '28722008.58', '1000000.00',
#        '5000000.00', '4000000.00', '43083012.88', '2800000.00',
#        '1700000.00', '1300000.00', '7180502.15', '17305010.17',
#        '21541506.44', '500000.00', '149354444.64', '64624519.31',
#        '13400000.00', '35902510.73', '37396055.18', '11488803.43',
#        '8616.60', '9000000.00', '100000.00', '20000.00', '120000.00',
#        '48827414.59', '491146346.79', '1430145.00', '861660257.52',
#        '74200000000.00', '14361004292.00', '28722008583.99',
#        '309800000.00', '14361.00', '359025107.30', '1000000000000.00',
#        '700000000.00', '3500000000.00', '789855236.06', '2805000000.00',
#        '200000000.00', '344664103.01', '172332051.50', '204000000.00',
# ...

# %%
df['Founded'].unique()
# Out:
# array([nan, 2014.0, 2004.0, 2013.0, 2010.0, 2018.0, 2019.0, 2017.0,
#        2011.0, 2015.0, 2016.0, 2012.0, 2008.0, '2019', '2018', '2020',
#        '2016', '2008', '2015', '2017', '2014', '1998', '2007', '2011',
#        '1982', '2013', '2009', '2012', '1995', '2010', '2006', '1978',
#        '1999', '1994', '2005', '1973', '-', '2002', '2004', '2001',
#        2021.0, 2020.0, 1993.0, 1999.0, 1989.0, 2009.0, 2002.0, 1994.0,
#        2006.0, 2000.0, 2007.0, 1978.0, 2003.0, 1998.0, 1991.0, 1984.0,
#        2005.0, 1963.0], dtype=object)

# %%
df['Founded'].isnull().sum()
# Out:
# 768

# %%
df[df['Founded'].isna()]
# Out:
#          Company/Brand                Sector       Stage HeadQuarter  \
# 0      TheCollegeFever       Brand Marketing        Seed   Bangalore
# 1      Happy Cow Dairy           Agriculture        Seed      Mumbai
# 2           MyLoanCare                Credit    Series A     Gurgaon
# 3          PayMe India    Financial Services       Angel       Noida
# 4             Eunimart  E-Commerce Platforms        Seed   Hyderabad
# ...                ...                   ...         ...         ...
# 1043            Quicko              Taxation         NaN   Ahmedabad
# 1044  Satin Creditcare               Fintech         NaN     Gurgaon
# 1050      Leverage Edu                Edtech         NaN       Delhi
# 1051             EpiFi               Fintech  Seed Round         NaN
# 137      Smart Express             Logistics        Seed      Mumbai
#
#                                            What it does    Amount($) Founded  \
# ...

# %%
df['Founded'] = df['Founded'].replace('-',0)

# %%
df['Founded'] = df['Founded'].replace(np.nan,0)

# %%
df['Founded'] = df['Founded'].astype(int)

# %%
df['Founded'] = df['Founded'].replace(0, 'N/A')

# %%
df['Founded'] = df['Founded'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2879 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  2879 non-null   object
#  1   Sector         2861 non-null   object
#  2   Stage          1941 non-null   object
#  3   HeadQuarter    2765 non-null   object
#  4   What it does   2879 non-null   object
#  5   Amount($)      2873 non-null   object
#  6   Founded        2879 non-null   object
#  7   Founders       2334 non-null   object
#  8   Investor       2253 non-null   object
#  9   Unnamed: 9     2 non-null      object
# dtypes: object(10)
# memory usage: 247.4+ KB

# %%
df
# Out:
#         Company/Brand                 Sector         Stage HeadQuarter  \
# 0     TheCollegeFever        Brand Marketing          Seed   Bangalore
# 1     Happy Cow Dairy            Agriculture          Seed      Mumbai
# 2          MyLoanCare                 Credit      Series A     Gurgaon
# 3         PayMe India     Financial Services         Angel       Noida
# 4            Eunimart   E-Commerce Platforms          Seed   Hyderabad
# ...               ...                    ...           ...         ...
# 1204         Gigforce  Staffing & Recruiting  Pre-series A    Gurugram
# 1205           Vahdam       Food & Beverages      Series D   New Delhi
# 1206     Leap Finance     Financial Services      Series C   Bangalore
# 1207     CollegeDekho                 EdTech      Series B    Gurugram
# 1208           WeRize     Financial Services      Series A   Bangalore
#
#                                            What it does    Amount($) Founded  \
# ...

# %%
df.update(df[['HeadQuarter','Sector','What it does', 'Founders', 'Investor','Stage']].fillna('N/A'))

# %%
df
# Out:
#         Company/Brand                 Sector         Stage HeadQuarter  \
# 0     TheCollegeFever        Brand Marketing          Seed   Bangalore
# 1     Happy Cow Dairy            Agriculture          Seed      Mumbai
# 2          MyLoanCare                 Credit      Series A     Gurgaon
# 3         PayMe India     Financial Services         Angel       Noida
# 4            Eunimart   E-Commerce Platforms          Seed   Hyderabad
# ...               ...                    ...           ...         ...
# 1204         Gigforce  Staffing & Recruiting  Pre-series A    Gurugram
# 1205           Vahdam       Food & Beverages      Series D   New Delhi
# 1206     Leap Finance     Financial Services      Series C   Bangalore
# 1207     CollegeDekho                 EdTech      Series B    Gurugram
# 1208           WeRize     Financial Services      Series A   Bangalore
#
#                                            What it does    Amount($) Founded  \
# ...

# %%
df['Unnamed: 9'].unique()
# Out:
# array([nan, 'Pre-Seed', 'Seed Round'], dtype=object)

# %%
df.drop('Unnamed: 9', inplace=True, axis=1)

# %%
df
# Out:
#         Company/Brand                 Sector         Stage HeadQuarter  \
# 0     TheCollegeFever        Brand Marketing          Seed   Bangalore
# 1     Happy Cow Dairy            Agriculture          Seed      Mumbai
# 2          MyLoanCare                 Credit      Series A     Gurgaon
# 3         PayMe India     Financial Services         Angel       Noida
# 4            Eunimart   E-Commerce Platforms          Seed   Hyderabad
# ...               ...                    ...           ...         ...
# 1204         Gigforce  Staffing & Recruiting  Pre-series A    Gurugram
# 1205           Vahdam       Food & Beverages      Series D   New Delhi
# 1206     Leap Finance     Financial Services      Series C   Bangalore
# 1207     CollegeDekho                 EdTech      Series B    Gurugram
# 1208           WeRize     Financial Services      Series A   Bangalore
#
#                                            What it does    Amount($) Founded  \
# ...

# %%
###stage

df['Stage'].unique()
# Out:
# array(['Seed', 'Series A', 'Angel', 'Series B', 'Pre-Seed',
#        'Private Equity', 'Venture - Series Unknown', 'Grant',
#        'Debt Financing', 'Post-IPO Debt', 'Series H', 'Series C',
#        'Series E', 'Corporate Round', 'Undisclosed', 'Undiscloded',
#        'Series D', 'Secondary Market', 'Post-IPO Equity',
#        'Non-equity Assistance', 'Funding Round', 'N/A', 'Fresh funding',
#        'Pre series A', 'Series G', 'Post series A', 'Seed funding',
#        'Seed fund', 'Series F', 'Series B+', 'Seed round', 'Pre-series A',
#        'Pre-seed', 'Pre-series', 'Debt', 'Pre-series C', 'Pre-series B',
#        'Bridge', 'Series B2', 'Pre- series A', 'Edge', 'Pre-Series B',
#        'Seed A', 'Series A-1', 'Seed Funding', 'Pre-seed Round',
#        'Seed Round & Series A', 'Pre Series A', 'Pre seed Round',
#        'Angel Round', 'Pre series A1', 'Series E2', 'Seed Round',
#        'Bridge Round', 'Pre seed round', 'Pre series B', 'Pre series C',
# ...

# %%
df[df['Stage'].str.contains('\$')]
# Out:
#         Company/Brand                  Sector     Stage     HeadQuarter  \
# 98            FanPlay          Computer Games  $1200000  Computer Games
# 111           FanPlay          Computer Games  $1200000  Computer Games
# 538       Little Leap                  EdTech   $300000       New Delhi
# 551             BHyve         Human Resources   $300000          Mumbai
# 674      MYRE Capital  Commercial Real Estate  $6000000          Mumbai
# 677  Saarthi Pedagogy                  EdTech  $1000000       Ahmadabad
#
#                                           What it does  \
# 98   A real money game app specializing in trivia g...
# 111  A real money game app specializing in trivia g...
# 538                Soft Skills that make Smart Leaders
# 551  A Future of Work Platform for diffusing Employ...
# 674                Democratising Real Estate Ownership
# 677  India's fastest growing Pedagogy company, serv...
#
#                            Amount($) Founded  \
# ...

# %%
new = df['Stage'].str.contains('\$')

# %%
df.loc[new, ['Stage', 'Amount($)']] = df.loc[new, ['Amount($)', 'Stage']].to_numpy()

# %%
df[df['Stage'].str.contains('\$',na=False)]
# Out:
# Empty DataFrame
# Columns: [Company/Brand, Sector, Stage, HeadQuarter, What it does, Amount($), Founded, Founders, Investor]
# Index: []

# %%
df['Stage'].unique()
# Out:
# array(['Seed', 'Series A', 'Angel', 'Series B', 'Pre-Seed',
#        'Private Equity', 'Venture - Series Unknown', 'Grant',
#        'Debt Financing', 'Post-IPO Debt', 'Series H', 'Series C',
#        'Series E', 'Corporate Round', 'Undisclosed', 'Undiscloded',
#        'Series D', 'Secondary Market', 'Post-IPO Equity',
#        'Non-equity Assistance', 'Funding Round', 'N/A', 'Fresh funding',
#        'Pre series A', 'Series G', 'Post series A', 'Seed funding',
#        'Seed fund', 'Series F', 'Series B+', 'Seed round', 'Pre-series A',
#        'Pre-seed', 'Pre-series', 'Debt', 'Pre-series C', 'Pre-series B',
#        'Bridge', 'Series B2', 'Pre- series A', 'Edge', 'Pre-Series B',
#        'Seed A', 'Series A-1', 'Seed Funding', 'Pre-seed Round',
#        'Seed Round & Series A', 'Pre Series A', 'Pre seed Round',
#        'Angel Round', 'Pre series A1', 'Series E2', 'Seed Round',
#        'Bridge Round', 'Pre seed round', 'Pre series B', 'Pre series C',
# ...

# %%
# Extract columns with foreign values
df[df['Stage'].str.contains('venture|network|upsparks|pe',case=False, na=False)]
# Out:
#                                       Company/Brand               Sector  \
# 94                                 Rays Power Infra               Energy
# 106                                 Vivriti Capital   Financial Services
# 118                            SEDEMAC Mechatronics           Automotive
# 119                                     MadGuy Labs           E-Learning
# 131                                         Wakefit        Manufacturing
# 132                                   Hero Electric        Manufacturing
# 138                                       Wow Venue               Events
# 143                                     MyNewCar.in           Automotive
# 152                                      Shopkirana           E-Commerce
# 153                                     Fric Bergen                    —
# 160                                      ION Energy               Energy
# 349  Wicked Ride Adventure Services Private Limited           Automotive
# ...

# %%
#replace foreign values with N/A
df.loc[df['Stage'].str.contains('venture|network|upsparks', case=False, na=False), 'Stage'] = 'N/A'

# %%
df['Stage'].unique()
# Out:
# array(['Seed', 'Series A', 'Angel', 'Series B', 'Pre-Seed',
#        'Private Equity', 'N/A', 'Grant', 'Debt Financing',
#        'Post-IPO Debt', 'Series H', 'Series C', 'Series E',
#        'Corporate Round', 'Undisclosed', 'Undiscloded', 'Series D',
#        'Secondary Market', 'Post-IPO Equity', 'Non-equity Assistance',
#        'Funding Round', 'Fresh funding', 'Pre series A', 'Series G',
#        'Post series A', 'Seed funding', 'Seed fund', 'Series F',
#        'Series B+', 'Seed round', 'Pre-series A', 'Pre-seed',
#        'Pre-series', 'Debt', 'Pre-series C', 'Pre-series B', 'Bridge',
#        'Series B2', 'Pre- series A', 'Edge', 'Pre-Series B', 'Seed A',
#        'Series A-1', 'Seed Funding', 'Pre-seed Round',
#        'Seed Round & Series A', 'Pre Series A', 'Pre seed Round',
#        'Angel Round', 'Pre series A1', 'Series E2', 'Seed Round',
#        'Bridge Round', 'Pre seed round', 'Pre series B', 'Pre series C',
# ...

# %% [raw]
# 'Undiscloded':'Undisclosed'
# 'Pre series A':'Pre-series A'

# %%
#replace misspelled stage names with the appropriate stage names 
df['Stage'] = df['Stage'].replace({'Undiscloded':'Undisclosed','Pre series A':'Pre-series A','Seed+':'Seed','Seed Round & Series A':'Series A','Seies A':'Series A','Series A-1':'Series A',
                                  'Series C,D':'Series C','Seed funding':'Seed','Seed fund':'Seed','Seed round':'Seed',}, regex=True)

# %%
df['Stage'].unique()
